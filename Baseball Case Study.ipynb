# %% [markdown]
# Baseball Case Study
#
# Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.
#
# Downlaod Files:
# https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %%
#Importing required packages & libraries.

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
#printing the dataset
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#checking the shape of dataset
df.shape
# Out:
# (30, 17)

# %%
#Checking the data types of all columns
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#Checking the information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Checking unique values of each columns
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
#Checking null values in dataset
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# We can see that the dataset has no null values.

# %%
#Checking value counts in our target column
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# Here too we can see there are no missing values.

# %%
#Checking description of dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# We can see that all the columns have a count value of 30 with no negative values.  There are few columns with have very low values while others have very high values.

# %% [markdown]
# Data Visualization:

# %%
plt.figure(figsize = (25,50), facecolor = 'yellow')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.distplot(df[column], color = 'blue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# Almost all the columns are normally distributed, except R,SO,CG and E.

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.histplot(df[column], color = 'blue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber += 1
plt.show()

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,3,plotnumber)
        sns.boxplot(df[column], color = 'green')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# As we can see in the boxplots R, ERA, SHO, SV and E have outliers. So,we need to remove the outliers now.

# %%
plt.figure(figsize = (25,50), facecolor = 'skyblue')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        ax = plt.subplot(7,4,plotnumber)
        plt.scatter(df[column],df['W'], color='g')
        plt.xlabel(column,fontsize=26)
        plt.ylabel('W', fontsize=26)
    plotnumber += 1
plt.tight_layout()

# %% [markdown]
# We can see in plot R, ERA, SHO and SV looks like having almost linear relationship with the target variable W while the other variables have non linear relationship.

# %%
plt.figure(figsize = (25,20), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        plt.figure(figsize = (10,6))
        sns.regplot(df[column], df['W'])
        plt.title('Scatter Plot for Wins vs other attributes')
        plt.xlabel(column)
        plt.ylabel('W')
        
plt.tight_layout()

# %% [markdown]
# We can see RA, ER and ERA have a good relation with W or win. The other columns does not show a good relation with W because the data is scattered all across.

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# We have the pair plots of each pair of features. We can check if one has a good correlation or not.

# %%
plt.figure(figsize = [15, 10])
sns.heatmap(df.corr(), annot = True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The heatmap shows there is little correlation. However, the columns RA, ER, ERA show high correlation to each other. We can also see that some columns have high negative correlation with W which means that the impact they have on winning is high. Thus, we will consider dropping two columns ER and RA and keep ERA as these have same kind of effect on wins. Thus, there will be no change in impact on the prediction model.

# %%
plt.figure(figsize =(25, 10))
df.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind ='bar', color ='skyblue')
plt.xlabel('Features')
plt.ylabel('Column with target names')
plt.title('Correlation')
plt.show()

# %% [markdown]
# As we can see from the correlation matrix that the graph of ER, RA and ERA have the strongest correlation with wins but the nature is negative.
#
# On the contrary, SV has the highest correlation of 0.67 followed by BB, SHO, R, 2B all above 0.4. This is a positive side.
#
# Even though ER, RA and ERA are very negatively correlated with W but they show the highest correlation amongst themselves which is over 0.99.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# We can see no null values.

# %% [markdown]
# Checking Outliers

# %%
df.plot(kind='box',fontsize=10,figsize=(15,15),color='b')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the box plot we can see that there are outliers in R, ERA, SHO, SV and E.

# %% [markdown]
# Removing Outliers

# %%
#Features having outliers
features=df[['R','ERA','SHO','SV','E']]

# %%
#applying zscore method

from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# We have successfully removed the outliers by using Zscore.

# %%
#Checking the shape of new dataset
df_new.shape
# Out:
# (29, 17)

# %%
#Checking shape of old dataset
df.shape
# Out:
# (30, 17)

# %%
#Checking the loss of data
dataloss = (((30-29)/30)*100)
dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# As we can see the dataloss after applying zscore method is 3.33%. This is less than 10%, which is a good number at this point.

# %% [markdown]
# Checking Skewness

# %%
#Checking for Skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# We can find skewness in H, CG, SHO, SV and E.

# %% [markdown]
# Removing Skewness

# %%
#skewed features
skew_features=["H","CG","SHO","SV","E"]

# %%
#Removing skewness in H using log1p
df_new["H"]=np.log1p(df_new["H"])

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %%
#Removing skewness using yeo-johnson
df_new[['E','SHO','SV','CG']] = scaler.fit_transform(df_new[['E','SHO','SV','CG']].values)

# %% [markdown]
# We have successfully removed skewness in E by using yeo-johnson method.

# %%
#Checking skewness after removing skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# We have got 0.0 skewness.

# %%
#Let's now check how he data distribution in each column of the skewed features.

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_new[skew_features]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df_new[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# We can see that the skewness is removed.

# %%
#splitting the columns
x = df_new.drop("W",axis=1)
y = df_new["W"]

# %%
#Importing necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
ss=StandardScaler()
X = pd.DataFrame(ss.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.501486 -0.813262
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.501486  0.159299
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.854612 -0.326982
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.363013 -0.570122
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.363013  0.159299
#
#          SV         E
# 0  1.643157 -0.471091
# 1  0.211006 -0.614898
# 2 -0.700362 -1.118222
# ...

# %%
#variance inflation factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       7.135035        R
# 1      18.488544       AB
# 2      10.482908        H
# 3       3.744093       2B
# 4       3.279780       3B
# 5       8.407335       HR
# 6       3.404853       BB
# 7       2.722210       SO
# 8       2.106693       SB
# 9     198.805677       RA
# 10   1824.006095       ER
# 11   1445.833737      ERA
# 12      3.067770       CG
# 13      3.635298      SHO
# 14      6.175570       SV
# 15      2.124219        E

# %% [markdown]
# There is multicolinearity in RA,ER,ERA. So let me drop RA and ER columns.

# %%
#droping ER
X = X.drop(["ER"],axis=1)

# %%
X.head(10)
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
# 5  1.856900  0.716535 -0.051906 -0.093474 -1.266972  1.743939  1.643442
# 6  0.712585 -0.447345 -0.553131 -1.625627 -1.167936  1.915843 -0.885522
# 7 -0.835605 -0.447345 -0.310580  0.260100  0.020490  0.196801 -0.550807
# 8  1.497899  1.752672  1.689389  1.202964  0.119526 -0.009484  0.230197
# 9  1.565212 -0.078310  0.349394  0.319029  0.020490  0.368705  0.695081
#
#          SO        SB        RA       ERA        CG       SHO        SV  \
# 0 -2.727623  0.905953 -0.664514 -0.511388 -0.501486 -0.813262  1.643157
# ...

# %% [markdown]
# There are dependent variables after removing multicolinearity.

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.069116        R
# 1       7.791456       AB
# 2       9.340727        H
# 3       3.227862       2B
# 4       3.125190       3B
# 5       7.474108       HR
# 6       3.323583       BB
# 7       2.786186       SO
# 8       1.787493       SB
# 9     142.535647       RA
# 10    141.460079      ERA
# 11      2.536866       CG
# 12      3.136960      SHO
# 13      2.630293       SV
# 14      2.272337        E

# %% [markdown]
# The variance inflation factor or VIF is high for 2 columns here. So, we will drop ERA.

# %%
#Droping RA
X = X.drop(["ERA"],axis=1)

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.019438        R
# 1       5.210230       AB
# 2       7.728111        H
# 3       3.165732       2B
# 4       2.981242       3B
# 5       6.168639       HR
# 6       3.053363       BB
# 7       2.287734       SO
# 8       1.773119       SB
# 9       4.759240       RA
# 10      2.522962       CG
# 11      3.121855      SHO
# 12      2.606434       SV
# 13      2.239918        E

# %% [markdown]
# Multicolinearity issue is solved.

# %%
#splitting the data for training and testing

from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import  LinearRegression

LR=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is :-0.9813108893294155
# At random state0, The test accuracy is :-0.32096661212058397
#
#
# At random state1, The training accuracy is :-0.9724616751681474
# At random state1, The test accuracy is :-0.5523441775760541
#
#
# At random state2, The training accuracy is :-0.9652138799490683
# At random state2, The test accuracy is :--0.18378012715973457
#
#
# At random state3, The training accuracy is :-0.9707643281024896
# At random state3, The test accuracy is :-0.5934123428669802
#
#
# At random state4, The training accuracy is :-0.9636066673589541
# At random state4, The test accuracy is :-0.777789247301591
#
#
# At random state5, The training accuracy is :-0.9617652055322028
# At random state5, The test accuracy is :-0.5635199544205843
#
#
# At random state6, The training accuracy is :-0.9759897747835667
# At random state6, The test accuracy is :-0.754344352256292
#
#
# At random state7, The training accuracy is :-0.9602880294971184
# ...

# %% [markdown]
# We can see highest accuracy at random state=99.

# %%
#Splitting the data into 78% training and 22% testing

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)

# %%
x_train.shape
# Out:
# (22, 16)

# %%
y_train.shape
# Out:
# (22,)

# %%
x_test.shape
# Out:
# (7, 16)

# %%
y_test.shape
# Out:
# (7,)

# %% [markdown]
# Model Building

# %%
#Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor 
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %%
#Linear Regression

from sklearn.linear_model import LinearRegression

LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.9604621132932195

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# MSE: 20.357441381233155
# MAE: 3.8670480863919203
# r2_score: 0.8813818314545505

# %%
#SGD

from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mae:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: -2.5307519302786724e+30
# mae: 3.4335589454066564e+32
# mae: 1.85137999157543e+16
# rmse: 1.8529864935845204e+16

# %%
#Lasso Regressor 
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
pred=ls.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8320459199016313
# mse: 22.786912744774586
# mae: 4.4546895021225295
# rmse: 4.7735639458139225

# %%
#Ridge Regressor
parameters={'alpha':[0.001,0.01,0.1,1,10],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
rd=Ridge()
Z1=GridSearchCV(rd,parameters)
Z1.fit(x_train,y_train)
print(Z1.best_params_)
# Out:
# {'alpha': 10, 'solver': 'saga'}

# %%
rd=Ridge(alpha=10,solver='lsqr')
rd.fit(x_train,y_train)
pred=rd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8098511500449889
# mse: 25.79815417348805
# mae: 4.450531834507664
# rmse: 5.079188338060329

# %%
#Cross Validation 

from sklearn.model_selection import cross_val_score

np.random.seed(10)
def rmse_cv(model,x,y):
    rmse =-(cross_val_score(model,x,y, scoring='neg_mean_squared_error', cv=10))
    return(rmse)

models = [LinearRegression(),
         Ridge(),
         SVR(kernel='linear'),
         SVR(kernel='poly'),
         SVR(kernel='rbf'),
         RandomForestRegressor(),
         DecisionTreeRegressor(),
         GradientBoostingRegressor(),]

names = ['LR','R','svr','svr_p','svr_r','RF','DTR','GBR']

for model,name in zip(models,names):
    score = rmse_cv(model,x,y)
    print("{}   : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR   : 33.227142, 22.206678
# R   : 32.549049, 32.609656
# svr   : 58.165562, 34.299786
# svr_p   : 111.891643, 79.768934
# svr_r   : 112.275451, 79.777668
# RF   : 39.864027, 24.023091
# DTR   : 70.216667, 45.490539
# GBR   : 47.569624, 31.099844

# %% [markdown]
# As per the metrics score selecting the LinearRegression as final model.

# %%
#Hyper Parameter Tuning

#Importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'alpha':[0.01,0.1,1.0,10.26],
            'selection':['cyclic','random'],
            'max_iter':[2,4,6,8,10],
            'tol':[100,1000],
            'fit_intercept':['bool']}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GVC.best_params_
# Out:
# {'alpha': 10.26,
#  'fit_intercept': 'bool',
#  'max_iter': 4,
#  'selection': 'random',
#  'tol': 100}

# %%
Final_mod=Lasso(alpha=1.0, fit_intercept="bool", max_iter=4, selection="random", tol=1000)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 80.9005339010049
# mean_squared_error: 25.91290829104479
# mean_absolute_error: 3.8691837338284754
# RMSE value: 5.090472305301817

# %% [markdown]
# After tuning we got an accuracy of 80.90%, a good one.

# %%
#Saving the model using .pkl
import joblib
joblib.dump(Final_mod,"Baseball Case Study.pkl")
# Out:
# ['Baseball Case Study.pkl']

# %%
#Loading the saved model
model=joblib.load("Baseball Case Study.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([69.85684995, 62.7112772 , 85.74951984, 74.24340833, 85.08653989,
#        87.49105772, 81.66384062])

# %% [markdown]
# The above are the predicted values.

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                   0          1         2          3         4          5  \
# Predicted  69.85685  62.711277  85.74952  74.243408  85.08654  87.491058
# Original   67.00000  63.000000  97.00000  76.000000  83.00000  92.000000
#
#                    6
# Predicted  81.663841
# Original   86.000000

# %% [markdown]
# We can see that both the original and predicted values are almost equal.
